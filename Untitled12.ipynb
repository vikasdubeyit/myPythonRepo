# %%
import numpy as np
import pandas as pd

# %%
from numpy.random import randn

# %%
np.random.seed(101)

# %%
df=pd.DataFrame(randn(5,4),['a','b','c','d','e'],['w','x','y','z'])

# %%
df
# Out:
#           w         x         y         z
# a  2.706850  0.628133  0.907969  0.503826
# b  0.651118 -0.319318 -0.848077  0.605965
# c -2.018168  0.740122  0.528813 -0.589001
# d  0.188695 -0.758872 -0.933237  0.955057
# e  0.190794  1.978757  2.605967  0.683509

# %%
df>0
# Out:
#        w      x      y      z
# a   True   True   True   True
# b   True  False  False   True
# c  False   True   True  False
# d   True  False  False   True
# e   True   True   True   True

# %%
booldf=df>0
df[booldf]
# Out:
#           w         x         y         z
# a  2.706850  0.628133  0.907969  0.503826
# b  0.651118       NaN       NaN  0.605965
# c       NaN  0.740122  0.528813       NaN
# d  0.188695       NaN       NaN  0.955057
# e  0.190794  1.978757  2.605967  0.683509

# %%
df[df>0]
# Out:
#           w         x         y         z
# a  2.706850  0.628133  0.907969  0.503826
# b  0.651118       NaN       NaN  0.605965
# c       NaN  0.740122  0.528813       NaN
# d  0.188695       NaN       NaN  0.955057
# e  0.190794  1.978757  2.605967  0.683509

# %%
df
# Out:
#           w         x         y         z
# a  2.706850  0.628133  0.907969  0.503826
# b  0.651118 -0.319318 -0.848077  0.605965
# c -2.018168  0.740122  0.528813 -0.589001
# d  0.188695 -0.758872 -0.933237  0.955057
# e  0.190794  1.978757  2.605967  0.683509

# %%
df['w']
# Out:
# a    2.706850
# b    0.651118
# c   -2.018168
# d    0.188695
# e    0.190794
# Name: w, dtype: float64

# %%
df['w']>0
# Out:
# a     True
# b     True
# c    False
# d     True
# e     True
# Name: w, dtype: bool

# %%
df[df['w']>0]
# Out:
#           w         x         y         z
# a  2.706850  0.628133  0.907969  0.503826
# b  0.651118 -0.319318 -0.848077  0.605965
# d  0.188695 -0.758872 -0.933237  0.955057
# e  0.190794  1.978757  2.605967  0.683509

# %%
df
# Out:
#           w         x         y         z
# a  2.706850  0.628133  0.907969  0.503826
# b  0.651118 -0.319318 -0.848077  0.605965
# c -2.018168  0.740122  0.528813 -0.589001
# d  0.188695 -0.758872 -0.933237  0.955057
# e  0.190794  1.978757  2.605967  0.683509

# %%
df[df['z']<0.6]
# Out:
#           w         x         y         z
# a  2.706850  0.628133  0.907969  0.503826
# c -2.018168  0.740122  0.528813 -0.589001

# %%
rdf=df[df['w']>0]

# %%
df[df['w']>0][['z','y']]
# Out:
#           z         y
# a  0.503826  0.907969
# b  0.605965 -0.848077
# d  0.955057 -0.933237
# e  0.683509  2.605967

# %%
df
# Out:
#           w         x         y         z
# a  2.706850  0.628133  0.907969  0.503826
# b  0.651118 -0.319318 -0.848077  0.605965
# c -2.018168  0.740122  0.528813 -0.589001
# d  0.188695 -0.758872 -0.933237  0.955057
# e  0.190794  1.978757  2.605967  0.683509

# %%
df[(df['w']>1) | (df['y']>0.7)]
# Out:
#           w         x         y         z
# a  2.706850  0.628133  0.907969  0.503826
# e  0.190794  1.978757  2.605967  0.683509

# %%
df.reset_index()
# Out:
#   index         w         x         y         z
# 0     a  2.706850  0.628133  0.907969  0.503826
# 1     b  0.651118 -0.319318 -0.848077  0.605965
# 2     c -2.018168  0.740122  0.528813 -0.589001
# 3     d  0.188695 -0.758872 -0.933237  0.955057
# 4     e  0.190794  1.978757  2.605967  0.683509

# %%
ni='ca ny dl jbp bhp'.split()
ni
# Out:
# ['ca', 'ny', 'dl', 'jbp', 'bhp']

# %%
df['States']=ni

# %%
df
# Out:
#           w         x         y         z States
# a  2.706850  0.628133  0.907969  0.503826     ca
# b  0.651118 -0.319318 -0.848077  0.605965     ny
# c -2.018168  0.740122  0.528813 -0.589001     dl
# d  0.188695 -0.758872 -0.933237  0.955057    jbp
# e  0.190794  1.978757  2.605967  0.683509    bhp

# %%
df
# Out:
#                w         x         y         z
# States
# ca      2.706850  0.628133  0.907969  0.503826
# ny      0.651118 -0.319318 -0.848077  0.605965
# dl     -2.018168  0.740122  0.528813 -0.589001
# jbp     0.188695 -0.758872 -0.933237  0.955057
# bhp     0.190794  1.978757  2.605967  0.683509

# %%
df.set_index('z')
# Out:
#                   w         x         y
# z
#  0.503826  2.706850  0.628133  0.907969
#  0.605965  0.651118 -0.319318 -0.848077
# -0.589001 -2.018168  0.740122  0.528813
#  0.955057  0.188695 -0.758872 -0.933237
#  0.683509  0.190794  1.978757  2.605967

# %%
df.reset_index()
# Out:
#   States         w         x         y         z
# 0     ca  2.706850  0.628133  0.907969  0.503826
# 1     ny  0.651118 -0.319318 -0.848077  0.605965
# 2     dl -2.018168  0.740122  0.528813 -0.589001
# 3    jbp  0.188695 -0.758872 -0.933237  0.955057
# 4    bhp  0.190794  1.978757  2.605967  0.683509

# %%
df.set_index('x',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4940/3932181457.py in <module>
# ----> 1 df.set_index('x',inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5449
#    5450         if missing:
# -> 5451             raise KeyError(f"None of {missing} are in the columns")
#    5452
#    5453         if inplace:
#
# KeyError: "None of ['x'] are in the columns"

# %%
os=['g1','g1','g1','g2','g2','g2']
ins=[1,2,3,1,2,3]
hier_index=list(zip(outside,inside))
hier_index=pd.MultiIndex.from_tuples(hier_index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4940/4208589158.py in <module>
#       1 os=['g1','g1','g1','g2','g2','g2']
#       2 ins=[1,2,3,1,2,3]
# ----> 3 hier_index=list(zip(outside,inside))
#       4 hier_index=pd.MultiIndex.from_tuples(hier_index)
#
# NameError: name 'outside' is not defined

# %%
p=randn(6,2)
q=['a','b']
df=pd.DataFrame(p,hier_index,q)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4940/191733006.py in <module>
#       1 p=randn(6,2)
#       2 q=['a','b']
# ----> 3 df=pd.DataFrame(p,hier_index,q)
#
# NameError: name 'hier_index' is not defined
